# %%
# Install dependencies
#%pip install anthropic python-dotenv

# Load env variables
from dotenv import load_dotenv
load_dotenv()

# Create and API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

def add_user_message(messages, content):
    messages.append({"role": "user", "content": content})

def add_assistant_message(messages, content):
    messages.append({"role": "assistant", "content": content})

def chat(messages, model=model, max_tokens=1000):
    response = client.messages.create(
        model=model,
        max_tokens=max_tokens,
        messages=messages
    )
    return response.content[0].text

# %%
messages = []

while True:
    user_input = input("")
    if user_input.lower() in ["exit", "quit"]:
        break
    add_user_message(messages, user_input)
    answer = chat(messages)
    add_assistant_message(messages, answer)
    print(f"Assistant: {answer}")
# Out:
# Assistant: Jens Stoltenberg is a Norwegian politician who served as the Secretary General of NATO from 2014 to 2024 and previously as Prime Minister of Norway.
# Assistant: 15 years ago, around 2009-2010, Jens Stoltenberg was serving as the Prime Minister of Norway for his second term, leading the Norwegian Labour Party and overseeing the country's government and policies.
